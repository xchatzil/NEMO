# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# the measurements
sim_dict_means ={'dt': 42.07, 'mst': 134.16, 'leach': 45.0, 'chain': 6512.23, 'nemo (random)': 61.66, 'nemo (med=50)': 44.24, 'nemo (med=25)': 47.39}
sim_dict_quantiles = {'dt': 67.35, 'mst': 215.28, 'leach': 71.24, 'chain': 11771.75, 'nemo (random)': 82.29, 'nemo (med=50)': 69.21, 'nemo (med=25)': 71.49}

sim_dict_w_means = {'dt': 42.07, 'mst': 134.16, 'leach': 44.49, 'chain': 3256.18, 'nemo (w=1, m=50)': 46.59, 'nemo (w=1, m=25)': 47.39, 
                    'nemo (w=2, m=50)': 47.76, 'nemo (w=2, m=25)': 58.43, 'nemo (w=ln[1, 50], m=50)': 47.82, 'nemo (w=ln[1, 50], m=25)': 53.73}
sim_dict_w_quantiles = {'dt': 67.35, 'mst': 215.28, 'leach': 70.93, 'chain': 5782.98, 'nemo (w=1, m=50)': 72.23, 'nemo (w=1, m=25)': 73.73, 
                        'nemo (w=2, m=50)': 71.31, 'nemo (w=2, m=25)': 74.96, 'nemo (w=ln[1, 50], m=50)': 74.69, 'nemo (w=ln[1, 50], m=25)': 78.88}

pl_dict_means = {'dt': 96.95, 'mst': 120.88, 'leach': 101.37, 'chain': 2107.39, 'nemo (random)': 189.67, 'nemo (med=50)': 99.58, 'nemo (med=25)': 102.97}
pl_dict_quantiles = {'dt': 240.08, 'mst': 293.21, 'leach': 246.74, 'chain': 4106.73, 'nemo (random)': 240.36, 'nemo (med=50)': 241.62, 'nemo (med=25)': 244.26}

pl_dict_w_means = {'dt': 96.95, 'mst': 120.88, 'leach': 99.5, 'chain': 3747.58, 'nemo (w=1, m=50)': 97.63, 'nemo (w=1, m=25)': 97.57, 
                   'nemo (w=2, m=50)': 98.4, 'nemo (w=2, m=25)': 98.28, 'nemo (w=ln[1, 50], m=50)': 118.72, 'nemo (w=ln[1, 50], m=25)': 118.41}
pl_dict_w_quantiles = {'dt': 240.08, 'mst': 293.21, 'leach': 244.64, 'chain': 7048.52, 'nemo (w=1, m=50)': 240.34, 'nemo (w=1, m=25)': 240.34, 
                       'nemo (w=2, m=50)': 241.17, 'nemo (w=2, m=25)': 241.17, 'nemo (w=ln[1, 50], m=50)': 241.6, 'nemo (w=ln[1, 50], m=25)': 241.6}

king_dict_means = {'dt': 300.13, 'mst': 632.51, 'leach': 312.76, 'chain': 23970.92, 'nemo (random)': 378.52, 'nemo (med=50)': 316.54, 'nemo (med=25)': 339.23}
king_dict_quantiles = {'dt': 383.13, 'mst': 1118.1, 'leach': 399.71, 'chain': 38318.19, 'nemo (random)': 500.66, 'nemo (med=50)': 420.92, 'nemo (med=25)': 465.26}

king_dict_w_means = {'dt': 300.13, 'mst': 632.51, 'leach': 311.53, 'chain': 21776.28, 'nemo (w=1, m=50)': 326.07, 'nemo (w=1, m=25)': 331.29, 
                     'nemo (w=2, m=50)': 331.93, 'nemo (w=2, m=25)': 322.19, 'nemo (w=ln[1, 50], m=50)': 389.38, 'nemo (w=ln[1, 50], m=25)': 391.24}
king_dict_w_quantiles = {'dt': 383.13, 'mst': 1118.1, 'leach': 396.35, 'chain': 41815.7, 'nemo (w=1, m=50)': 409.52, 'nemo (w=1, m=25)': 421.28,
                     'nemo (w=2, m=50)': 430.95, 'nemo (w=2, m=25)': 425.51, 'nemo (w=ln[1, 50], m=50)': 496.83, 'nemo (w=ln[1, 50], m=25)': 531.1} 

fit_dict_means = {'dt': 15.49, 'mst': 37.46, 'leach': 17.19, 'chain': 1339.24, 'nemo (random)': 23.58, 'nemo (med=50)': 17.87, 'nemo (med=25)': 17.66}
fit_dict_quantiles = {'dt': 22.87, 'mst': 56.12, 'leach': 24.48, 'chain': 2525.46, 'nemo (random)': 42.0, 'nemo (med=50)': 24.47, 'nemo (med=25)': 24.88}

fit_dict_w_means = {'dt': 15.49, 'mst': 37.46, 'leach': 16.81, 'chain': 848.67, 'nemo (w=1, m=50)': 15.94, 'nemo (w=1, m=25)': 17.52, 
                    'nemo (w=2, m=50)': 18.4, 'nemo (w=2, m=25)': 19.33, 'nemo (w=ln[1, 50], m=50)': 18.83, 'nemo (w=ln[1, 50], m=25)': 20.06}
fit_dict_w_quantiles = {'dt': 22.87, 'mst': 56.12, 'leach': 24.89, 'chain': 1533.59, 'nemo (w=1, m=50)': 22.94, 'nemo (w=1, m=25)': 24.69, 
                        'nemo (w=2, m=50)': 24.98, 'nemo (w=2, m=25)': 26.96, 'nemo (w=ln[1, 50], m=50)': 27.47, 'nemo (w=ln[1, 50], m=25)': 28.54}

atlas_dict_means = {'dt': 225.7, 'mst': 568.15, 'leach': 235.8, 'chain': 8520.43, 'nemo (random)': 291.48, 'nemo (med=50)': 238.22, 'nemo (med=25)': 244.56}
atlas_dict_quantiles = {'dt': 276.26, 'mst': 781.92, 'leach': 286.08, 'chain': 16422.76, 'nemo (random)': 387.45, 'nemo (med=50)': 292.75, 'nemo (med=25)': 296.03}

atlas_dict_w_means = {'dt': 225.7, 'mst': 568.15, 'leach': 235.45, 'chain': 7225.13, 'nemo (w=1, m=50)': 230.11, 'nemo (w=1, m=25)': 231.14, 
                      'nemo (w=2, m=50)': 233.04, 'nemo (w=2, m=25)': 232.56, 'nemo (w=ln[1, 50], m=50)': 285.87, 'nemo (w=ln[1, 50], m=25)': 301.09}
atlas_dict_w_quantiles = {'dt': 276.26, 'mst': 781.92, 'leach': 284.71, 'chain': 16434.16, 'nemo (w=1, m=50)': 279.58, 'nemo (w=1, m=25)': 279.58, 
                          'nemo (w=2, m=50)': 281.7, 'nemo (w=2, m=25)': 287.39, 'nemo (w=ln[1, 50], m=50)': 357.29, 'nemo (w=ln[1, 50], m=25)': 408.44}

# %%
#columns = ['direct_trx', 'mst', 'leach', 'chain', 'nemo (rdm)', 'nemo (m=50)', 'nemo (m=25)']
columns = ['direct_trx', 'mst', 'leach', 'chain', 'nemo (w=1, m=50)', 'nemo (w=1, m=25)', 'nemo (w=2, m=50)', 'nemo (w=2, m=25)', 'nemo (w=ln[1, 50], m=50)', 'nemo (w=ln[1, 50], m=25)']
rows = ['sim (1000)', 'PlanetLab', 'King', 'FIT', 'RIPEAtlas']

data_mean = {'sim_dict_means': sim_dict_w_means,
        'pl_dict_means': pl_dict_w_means,
        'king_dict_means': king_dict_w_means,
        'fit_dict_means': fit_dict_w_means,
        'atlas_dict_means': atlas_dict_w_means}

data_p90 = {'sim_dict_quantiles': sim_dict_w_quantiles,
        'pl_dict_quantiles': pl_dict_w_quantiles,
        'king_dict_quantiles': king_dict_w_quantiles,
        'fit_dict_quantiles': fit_dict_w_quantiles,
        'atlas_dict_quantiles': atlas_dict_w_quantiles}

# %%
df_mean = pd.DataFrame.from_dict(data_mean, orient='index')
df_p90 = pd.DataFrame.from_dict(data_p90, orient='index')

#Convert the DataFrame to integers
df_mean = df_mean.astype(int)
df_p90 = df_p90.astype(int)

# %%
df_mean
# Out:
#                    dt  mst  leach  chain  nemo (w=1, m=50)  nemo (w=1, m=25)  \
# sim_dict_means     42  134     44   3256                46                47
# pl_dict_means      96  120     99   3747                97                97
# king_dict_means   300  632    311  21776               326               331
# fit_dict_means     15   37     16    848                15                17
# atlas_dict_means  225  568    235   7225               230               231
#
#                   nemo (w=2, m=50)  nemo (w=2, m=25)  \
# sim_dict_means                  47                58
# pl_dict_means                   98                98
# king_dict_means                331               322
# fit_dict_means                  18                19
# atlas_dict_means               233               232
#
#                   nemo (w=ln[1, 50], m=50)  nemo (w=ln[1, 50], m=25)
# sim_dict_means                          47                        53
# ...

# %%
df_p90
# Out:
#                        dt   mst  leach  chain  nemo (w=1, m=50)  \
# sim_dict_quantiles     67   215     70   5782                72
# pl_dict_quantiles     240   293    244   7048               240
# king_dict_quantiles   383  1118    396  41815               409
# fit_dict_quantiles     22    56     24   1533                22
# atlas_dict_quantiles  276   781    284  16434               279
#
#                       nemo (w=1, m=25)  nemo (w=2, m=50)  nemo (w=2, m=25)  \
# sim_dict_quantiles                  73                71                74
# pl_dict_quantiles                  240               241               241
# king_dict_quantiles                421               430               425
# fit_dict_quantiles                  24                24                26
# atlas_dict_quantiles               279               281               287
#
#                       nemo (w=ln[1, 50], m=50)  nemo (w=ln[1, 50], m=25)
# ...

# %%
# create the heatmap
df = df_mean.copy()
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(df, annot=True, cmap='viridis_r', vmax=500, cbar_kws={'label': 'latency (ms)'}, xticklabels=columns, cbar=True, yticklabels=rows, fmt='g')

# Rotate xtick labels
plt.xticks(rotation=35, ha='right')

# show the plot
plt.savefig("plots/heatmap_means.svg", bbox_inches='tight')
plt.title("Average Latency")
plt.show()

# %%
# create the heatmap
df = df_p90.copy()
plt.figure(figsize=(6, 2))
sns.set(font_scale=1)
sns.heatmap(df, annot=True, cmap='viridis_r', vmax=500, cbar_kws={'label': 'latency (ms)'}, xticklabels=columns, cbar=True, yticklabels=rows, fmt='g')

# Rotate xtick labels
plt.xticks(rotation=22, ha='right')

# show the plot
plt.savefig("plots/heatmap_p90.svg", bbox_inches='tight')
plt.title("P90 Latency")
plt.show()

# %%
# create the heatmap
df = df_mean.copy()
df = df.div(df.min(axis=1), axis=0)
df = df.drop("dt", axis=1)
new_cols = columns[1:]

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(df, annot=True, cmap='viridis_r', vmax=3, cbar_kws={'label': 'latency (ms)'}, cbar=True, xticklabels=new_cols, yticklabels=rows, fmt='.2f')

# Rotate xtick labels
plt.xticks(rotation=35, ha='right')

# show the plot
plt.savefig("plots/heatmap_means_norm.svg", bbox_inches='tight')
plt.title("Normalized Average Latency")
plt.show()

# %%
# create the heatmap
df = df_p90.copy()
df = df.div(df.min(axis=1), axis=0)
df = df.drop("dt", axis=1)
new_cols = columns[1:]

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(df, annot=True, cmap='viridis_r', vmax=3, cbar_kws={'label': 'latency (ms)'}, cbar=True, xticklabels=new_cols, yticklabels=rows, fmt='.2f')

# Rotate xtick labels
plt.xticks(rotation=35, ha='right')

# show the plot
plt.savefig("plots/heatmap_p90_norm.svg", bbox_inches='tight')
plt.title("Normalized P90 Latency")
plt.show()
